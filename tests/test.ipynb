# %%
import os
import time
os.chdir("/home/mdawkins/Projects")

# %%
from checkersmate.Game import Game
from checkersmate.Rules import *
from Player import random_player

# %%
state = Game()

# %%
print(state)
# Out:
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 | x |   | x |   | x |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H

# %%
legal_simple_moves_given_square(state,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-120c8e703861> in <module>
# ----> 1 legal_simple_moves_given_square(state,10)
#
# ~/Projects/Checkersmate/Rules/Simple_move.py in legal_simple_moves_given_square(game, i)
#      11         if game.board[base] >= 1:
#      12             if (left <= 31):
# ---> 13                 if (row_diff(base,left)==1) & (game.board[left]==0):
#      14                     legal_moves.append(update_board_simple_move(game,base,left))
#      15             if (right <= 31):
#
# NameError: name 'row_diff' is not defined

# %%
for i in range(10):
    state = Game(random_player.select_move(legal_moves(state)),state.turn)
    print(state.turn)
    print(state)
    
    state.change_turn()
    print(state.turn)
    time.sleep(2)
# Out:
# 1
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   | x |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 | x |   | x |   |   |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# -1
# -1
#  ___________Checkersmate____________
#     white's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | x |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 7 | x |   | x |   | x |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   | x |   |   |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   | x |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   | o |
#   |---+---+---+---+---+---+---+---|
# 3 | o |   | o |   | o |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 1 | o |   | o |   | o |   | o |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# 1
# 1
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 5 | o |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   | x |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 | x |   | x |   | x |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   |   |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# -1
# -1
#  ___________Checkersmate____________
#     white's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | x |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 7 | x |   | x |   |   |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   | x |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   | x |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   | o |
#   |---+---+---+---+---+---+---+---|
# 3 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | o |   | o |   | o |   |   |
#   |---+---+---+---+---+---+---+---|
# 1 | o |   | o |   | o |   | o |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# 1
# 1
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 |   |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 5 | o |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   | x |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 | x |   | x |   | x |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   |   |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# -1
# -1
#  ___________Checkersmate____________
#     white's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | x |   |   |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 7 | x |   | x |   | x |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   | x |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   | x |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   | o |
#   |---+---+---+---+---+---+---+---|
# 3 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 1 | o |   | o |   | o |   |   |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# 1
# 1
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   |   |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 5 | o |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 3 | x |   | x |   | x |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   |   |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# -1
# -1
#  ___________Checkersmate____________
#     white's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | x |   |   |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 7 | x |   | x |   | x |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 5 | x |   | x |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   | o |   |   |   |   |   | o |
#   |---+---+---+---+---+---+---+---|
# 3 |   |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 1 | o |   | o |   | o |   |   |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# 1
# 1
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   |   |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   | o |   | o |   | o |   |   |
#   |---+---+---+---+---+---+---+---|
# 5 | o |   |   |   | x |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   | x |
#   |---+---+---+---+---+---+---+---|
# 3 | x |   | x |   | x |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   |   |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# -1
# -1
#  ___________Checkersmate____________
#     white's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | x |   |   |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 7 | x |   | x |   | x |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 5 | x |   | o |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   | x |   |   |   | o |
#   |---+---+---+---+---+---+---+---|
# 3 |   |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 1 | o |   | o |   | o |   |   |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
# 1

# %%
from random import randint
randint(2,5)
# Out:
# 3

# %%
for board in legal_moves(state):
    print(Game(board))
# Out:
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 | x |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   |   |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 |   |   | x |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   |   |   | x |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 |   |   | x |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   |   |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 |   |   |   |   | x |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   |   |   | x |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 |   |   |   |   | x |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   | x |   |   |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 |   |   |   |   |   |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   | x |   |   |   | x |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H
#  ___________Checkersmate____________
#     red's turn
#   +---+---+---+---+---+---+---+---+
# 8 |   | o |   | o |   | o |   | o |
#   |---+---+---+---+---+---+---+---|
# 7 | o |   | o |   | o |   | o |   |
#   |---+---+---+---+---+---+---+---|
# 6 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 5 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 4 |   |   |   |   |   |   |   |   |
#   |---+---+---+---+---+---+---+---|
# 3 |   |   |   |   |   |   | x |   |
#   |---+---+---+---+---+---+---+---|
# 2 |   | x |   | x |   | x |   |   |
#   |---+---+---+---+---+---+---+---|
# 1 | x |   | x |   | x |   | x |   |
#   +---+---+---+---+---+---+---+---+
#     A   B   C   D   E   F   G   H

# %%
[-x for x in [1,2,3][::-1]]
# Out:
# [-3, -2, -1]
